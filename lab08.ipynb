# %% [markdown]
# **Lab 8**
#
# Install langchain, cohere (for key), langchain-community. Get the api key( By logging into Cohere and obtaining the cohere key). Load a text document from your google drive . Create a prompt template to display the output in a particular manner.

# %%
import cohere
import getpass
from string import Template

file_path = "Teaching.txt"

try:
    with open(file_path, "r", encoding="utf-8") as file:
        text_content = file.read()
        print("File loaded successfully!")
except Exception as e:
    print("Error loading file:", str(e))

COHERE_API_KEY = getpass.getpass("Enter your Cohere API Key: ")

co = cohere.Client(COHERE_API_KEY)

template = Template("""
You are an AI assistant helping to summarize and analyze a text document.

Here is the document content:
$text

Summary:
Provide a concise summary of the document.
""")

formatted_prompt = template.substitute(text=text_content)

response = co.chat(
    model="command-r-08-2024",
    message=formatted_prompt
)

print("\n **Formatted Output** ")
print(response.text)
# Out:
# File loaded successfully!
#
#  **Formatted Output**
# The document highlights the essence of teaching as a process of imparting knowledge, skills, and values to learners. Effective teaching requires clear communication, patience, and an understanding of student needs. Teachers employ various methods, including lectures, discussions, practical activities, and technology, to enhance learning. In today's education, digital tools and online platforms play a crucial role in extending the reach of teachers beyond traditional classrooms. Ultimately, good teaching not only boosts academic performance but also fosters critical thinking, creativity, and problem-solving skills in students.
